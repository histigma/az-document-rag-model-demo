# %%
# !pip install finance-datareader

# %%
import FinanceDataReader as fdr

price_df = fdr.DataReader('005930')

price_df
# Out:
#               Open    High     Low   Close    Volume    Change
# Date
# 2013-08-13   24880   25800   24840   25800    418589       NaN
# 2013-08-14   25780   26000   25700   26000    260102  0.007752
# 2013-08-16   25720   26020   25640   25900    228332 -0.003846
# 2013-08-19   25720   25920   25600   25720    129997 -0.006950
# 2013-08-20   25920   26100   25380   25380    284619 -0.013219
# ...            ...     ...     ...     ...       ...       ...
# 2025-10-30  102400  105800  102000  104100  34570017  0.035821
# 2025-10-31  105000  108600  103300  107500  54824564  0.032661
# 2025-11-03  106900  111500  106500  111100  30110066  0.033488
# 2025-11-04  111800  112400  104900  104900  30450281 -0.055806
# 2025-11-05  101000  102000   96700  100600  44829894 -0.040991
#
# [3000 rows x 6 columns]
